# %%
import pandas as pd
import numpy as np

# %%
surveys_df = pd.read_csv("data/Practica_8/surveys.csv")

# %%
species_df =  pd.read_csv("data/Practica_8/species.csv")

# %%
survey_sub = surveys_df.head(10)
survey_sub
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN

# %%
survey_sub_last10 = surveys_df.tail(10)
survey_sub_last10 = survey_sub_last10.reset_index(drop=True)
survey_sub_last10
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
pd.concat([survey_sub, survey_sub_last10])
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
set(species_df.columns).intersection(set(surveys_df.columns))
# Out:
# {'species_id'}

# %%
species_df.merge(surveys_df, on = 'species_id', how = 'inner').shape
# Out:
# (34786, 12)

# %%
surveys_df.merge(species_df, on = 'species_id', how = 'left').shape
# Out:
# (35549, 12)

# %%
surveys_df.merge(species_df, on = 'species_id', how = 'right').shape
# Out:
# (34792, 12)

# %%
surveys_df.merge(species_df, on = 'species_id', how = 'outer').shape
# Out:
# (35555, 12)

# %%
df=surveys_df.groupby('species_id').count()

# %%
surveys_df.merge(species_df, on = 'species_id', how = 'left').to_csv('data/encuestas.csv', index=False)
