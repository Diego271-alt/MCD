# %%
# install.packages("datos")
# install.packages("ggplot2")
library(datos)
library(ggplot2)
library(nlme)

# %% [markdown]
# ## 1 Dimensión

# %% [markdown]
# ### Histograma

# %%
ggplot(diamantes, aes(quilate)) +
  geom_histogram() +
  ggtitle("Histograma para quilate")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(diamantes, aes(quilate, color = corte)) + # Se agrega variable categórica a la estética - Apilar la contirbución de cada categoría en el intervalo
  geom_histogram() +
  ggtitle("Histograma para quilate")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## Polígono de frequencia

# %%
ggplot(diamantes, aes(quilate)) +
  geom_freqpoly() +
  ggtitle("Polígono de frecuencia")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
ggplot(diamantes, aes(quilate, color = corte)) +
  geom_freqpoly() +
  ggtitle("Polígono de frecuencia")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# ## 2 Dimensiones

# %% [markdown]
# ### Diagrama de dispersión

# %%
# Dentro de la estética agregar color
ggplot(data = millas) +
  geom_point(mapping = aes(x = cilindrada, y = autopista, color = clase)) +
  ggtitle("Diagrama de dispersión") +
  labs(x = "Cilindrada", y = "Autopista")
# Out:
# plot without title

# %%
ggplot(millas, aes(traccion, autopista)) +
  geom_point() +
  ggtitle("Diagrama de dispersión") +
  labs(x = "Tracción", y = "Autopista")
# Out:
# plot without title

# %%
ggplot(Oxboys, aes(age, height, group = Subject, color = Subject)) + # Agrupar y colorear en función de una variable
  geom_point() +
  geom_line() +
  ggtitle("Diagrama de dispersión agrupado")
# Out:
# plot without title

# %%
ggplot(Oxboys, aes(age, height, group = Subject, color = Subject)) +
  geom_line() +
  geom_smooth() + # Ajusta un modelo de regresión (por cada grupo en la capa)
  ggtitle("Diagrama de dispersión agrupado")
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# ### Diagrama de dispersión

# %%
ggplot(millas, aes(traccion, autopista)) +
  geom_boxplot() +
  ggtitle("Boxplot") +
  labs(x = "Tracción", y = "Autopista")
# Out:
# plot without title

# %%
ggplot(millas, aes(clase, autopista)) +
  geom_boxplot() +
  ggtitle("Boxplot") +
  labs(x = "Clase", y = "Autopista") +
  coord_flip() # Cambiar el eje
# Out:
# plot without title

# %%
ggplot(Oxboys, aes(Occasion, height)) +
  geom_boxplot() +
  geom_line(aes(group = Subject), color = "blue")
# Out:
# plot without title

# %% [markdown]
# ### Diagrama de violín

# %%
ggplot(millas, aes(traccion, autopista)) +
  geom_violin() +
  ggtitle("Diagrama de violín") +
  labs(x = "Tracción", y = "Autopista")
# Out:
# plot without title
