# %%
# install.packages("dplyr")
# install.packages("ggplot2")
library(dplyr)
library(ggplot2)

# %%
head(economics, 3)
# Out:
#   date       pce   pop    psavert uempmed unemploy
# 1 1967-07-01 506.7 198712 12.6    4.5     2944
# 2 1967-08-01 509.8 198911 12.6    4.7     2945
# 3 1967-09-01 515.6 199113 11.9    4.6     2958

# %%
ggplot(economics, aes(date, psavert)) +
  geom_line() +
  labs(x = NULL, y = NULL)
# Out:
# plot without title

# %%
ggplot(economics, aes(date, psavert)) +
  geom_line() +
  labs(x = NULL, y = NULL) +
  scale_x_date(date_breaks = '15 years')  # Cortes en el eje x
# Out:
# plot without title

# %%
ggplot(economics, aes(date, psavert)) +
  geom_line() +
  labs(x = NULL, y = NULL) +
  scale_x_date(date_breaks = '8 years', date_labels = '%B\n%Y') # Personalizar el eje X
# Out:
# plot without title

# %%
anio = as.Date(c('2025-01-01', '2025-12-31'))
saltos <- scales::breaks_width('1 month')
saltos(anio)
# Out:
#  [1] "2025-01-01" "2025-02-01" "2025-03-01" "2025-04-01" "2025-05-01"
#  [6] "2025-06-01" "2025-07-01" "2025-08-01" "2025-09-01" "2025-10-01"
# [11] "2025-11-01" "2025-12-01" "2026-01-01"
